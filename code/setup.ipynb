# %% [markdown]
# # Python Set-up
# This is a file to help you set up the required python packages to run all notebooks in this repository. The code runs with Python 3.9.19

# %%
# install requirements file
# !pip install -r requirements.txt
